# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
import spacy
import string
from nltk.corpus import stopwords
import math
from operator import itemgetter
from collections import Counter

import pandas as pd
import re
import json

# %%
df = pd.read_json("data/wikipedia_sample.json", lines=True)
df.head()
# Out:
#           id                  name            wiki-title        gender  \
# 0   Q4647484        A. A. Phillips        A. A. Phillips  ['Q6581097']
# 1  Q20638732  A. F. Mujibur Rahman  A. F. Mujibur Rahman  ['Q6581097']
# 2   Q5304508             A. L. Rao             A. L. Rao  ['Q6581097']
# 3   Q2743474          A. N. Hornby          A. N. Hornby  ['Q6581097']
# 4   Q4648519    A. W. Rabi Bernard    A. W. Rabi Bernard  ['Q6581097']
#
#                               occupation  \
# 0                           ['Q4263842']
# 1                            ['Q170790']
# 2                                     []
# 3  ['Q12299841', 'Q937857', 'Q14089670']
# 4                             ['Q82955']
#
#                                             overview
# 0  '''Arthur Angell Phillips''' (1900–1985), gene...
# 1  '''Abul Faiz Mujibur Rahman''' was born on Sep...
# 2  '''A. Lakshman Rao''' is the former [[Chief Op...
# 3  '''Albert Neilson Hornby''', nicknamed '''Monk...
# 4  '''A. W. Rabi Bernard''' is an Indian politici...

# %%
def clear_overview(dirty_overview):
    # remove the <ref> </ref>
    overview = re.sub('<ref.*</ref>', '', dirty_overview)
    overview = re.sub('<ref.*/>', '', overview)

    # remove {{ }} and what is inside
    overview = re.sub('[\{].*[\}]', '', overview)
    
    # reomve [[File: ]] and [[Image: ]] and what is inside
    overview = re.sub('\[\[File:.*?\]\]', '', overview)
    overview = re.sub('\[\[Image:.*?\]\]', '', overview)

    # remove [[ ]] and keep what is inside and for the cases like [[abc | def]] keep only def and remove the rest
    overview = re.sub(r'\[\[(?:[^\]|]*\|)?([^\]|]*)\]\]', r'\1', overview)

    # remove ''' ''' 
    overview = re.sub('\'{2,3}', '', overview)

    # remove \n
    overview = re.sub('\n', '', overview)
    
    return overview

# %%
df.overview = df.overview.map(lambda x: clear_overview(x))
df.iloc[0].overview
# Out:
# 'Arthur Angell Phillips (1900–1985), generally known as A. A. Phillips, was an Australian writer, critic and teacher, best known for coining the term "Cultural Cringe" in his pioneering essay The Cultural Cringe (1950), which set the early terms for post-colonial theory in Australia. He was educated at Melbourne Grammar School and at the Universities of Melbourne and Oxford, and later taught at Wesley College in Melbourne.The Cultural Cringe was first published in the Melbourne cultural affairs journal Meanjin. It explored ingrained feelings of inferiority that local intellectuals struggled against, and which were most clearly pronounced in the Australian theatre, music, art and letters. Phillips pointed out that the public widely assumed that anything produced by local dramatists, actors, musicians, artists and writers was necessarily deficient when compared against the works of European counterparts. The only ways local arts professionals could build themselves up in public esteem was either to follow overseas fashions, or, more often, to spend a period of time working in Britain. In some professions this attitude even affected employment opportunities, with only those who had worked in London being treated as worthy of appointment or promotion. Thus the cultural cringe brought about over the early to mid 20th century a pattern of temporary residence in Britain for so many young talented Australians across a broad range of fields, from the arts to the sciences.Phillips\'s influential and highly controversial essay served as the focus in his later book The Australian Tradition: Essays in Colonial Culture (1958).'

# %% [markdown]
# ## NLP

# %%
nlp = spacy.load('en')

# %%
def is_adjective(token):
    if not token.is_stop:
        if token.pos_ == 'ADJ':
            return True
        else:
            return False
    else:
        return False

# %%
def get_adjectives(overview):
    doc = nlp(overview)
    adjs = [token.lemma_ for token in doc if is_adjective(token)]
    return adjs

# %%
df['adjectives'] = ''

# %%
df['adjectives'] = df.overview.map(lambda x: get_adjectives(x))

# %%
df.head()
# Out:
#           id                  name            wiki-title        gender  \
# 0   Q4647484        A. A. Phillips        A. A. Phillips  ['Q6581097']
# 1  Q20638732  A. F. Mujibur Rahman  A. F. Mujibur Rahman  ['Q6581097']
# 2   Q5304508             A. L. Rao             A. L. Rao  ['Q6581097']
# 3   Q2743474          A. N. Hornby          A. N. Hornby  ['Q6581097']
# 4   Q4648519    A. W. Rabi Bernard    A. W. Rabi Bernard  ['Q6581097']
#
#                               occupation  \
# 0                           ['Q4263842']
# 1                            ['Q170790']
# 2                                     []
# 3  ['Q12299841', 'Q937857', 'Q14089670']
# 4                             ['Q82955']
#
#                                             overview  \
# 0  Arthur Angell Phillips (1900–1985), generally ...
# 1  Abul Faiz Mujibur Rahman was born on September...
# 2  A. Lakshman Rao is the former Chief Operating ...
# 3  Albert Neilson Hornby, nicknamed Monkey Hornby...
# 4  A. W. Rabi Bernard is an Indian politician and...
#
#                                           adjectives
# 0  [australian, pioneering, early, post, -, colon...
# 1                                                 []
# 2      [outwipro, ecil, keynote, 2nd, distinguished]
# 3                                       [nineteenth]
# 4       [indian, incumbent, international, national]

# %%
df[df.adjectives.str.len() > 30]
# Out:
#               id                         name  \
# 745     Q4910214                  Bill Moisan
# 900      Q727006                  Béla Imrédy
# 1916    Q5442264  Felix Magalela Mafa Sibanda
# 1973    Q5480874                Francis Fagan
# 1999    Q3527396                 Frank Foster
# 2276    Q2653458              Ghillean Prance
# 2384    Q5605615                   Greg Gogan
# 2558   Q16934229                 Helen Tenney
# 2611   Q11708999              Henryk Jasiczek
# 2868    Q4141387               Jack Goldstone
# 3125    Q6176033             Jeffrey Harbeson
# 3290    Q6217926                 John A. Ryan
# 3463    Q6264281            John William Ward
# 3941    Q6504755                Lawrence Wnuk
# 4099    Q6694896                  Lu Lingxuan
# 4403   Q18629579              Marya Krasińska
# 4794   Q27983491               Newman Knowlys
# 4814    Q7027701                   Nick Peros
# 4898    Q3424347                Nun of Watton
# 5080    Q7153520                 Paul Sellers
# 5130    Q7172203               Pete Podgorski
# 5149    Q1699181                 Peter Dawson
# 5538     Q737739               Robert Muldoon
# 5585    Q7358506                   Roger Lane
# 5700    Q2087519        Rǫgnvaldr Guðrøðarson
# 5746   Q16316637             Sampoornesh Babu
# 6053    Q7599879              Stanley Porteus
# 6732    Q1806278       William Goodsir-Cullen
# 6909    Q5977726                     Zhu Hong
# 7201    Q2644744                  Alfred Boyd
# 7484    Q4798444         Arthur Defensor, Sr.
# 7566    Q4849108            Baker Abdel Munem
# 7655     Q514026                 Bernd Franke
# 7664     Q359442               Bernie Sanders
# 8347    Q3017762                David Derodon
# 8424      Q16977                Deng Xiaoping
# 8441    Q3273051                      Derebey
# 8640    Q3048654       Edward Willis Redfield
# 8914     Q123150          Francesco Borromini
# 9148     Q634125               George Gerbner
# 10327    Q351785                  John Murray
# 11075   Q6697285                 Lucille Kahn
# 11098  Q15993692                 Luis Zuloaga
# 11196   Q1923205                Manuel Peláez
# 11742   Q6969833             Nathaniel Rogers
# 11749   Q6982872                Nawang Sherpa
# 12287   Q3417342            Raffaele Garrucci
# 12331   Q2077572              Raoul de Boigne
# 13572   Q4017962                Walter Maioli
#
#                               wiki-title        gender  \
# 745                          Bill Moisan  ['Q6581097']
# 900                          Béla Imrédy  ['Q6581097']
# 1916         Felix Magalela Mafa Sibanda  ['Q6581097']
# 1973                       Francis Fagan  ['Q6581097']
# 1999            Frank Foster (cricketer)  ['Q6581097']
# 2276                     Ghillean Prance  ['Q6581097']
# 2384                          Greg Gogan  ['Q6581097']
# 2558                        Helen Tenney  ['Q6581072']
# 2611                     Henryk Jasiczek  ['Q6581097']
# 2868                      Jack Goldstone  ['Q6581097']
# 3125                    Jeffrey Harbeson  ['Q6581097']
# 3290                        John A. Ryan  ['Q6581097']
# 3463       John William Ward (professor)  ['Q6581097']
# 3941                       Lawrence Wnuk  ['Q6581097']
# 4099                         Lu Lingxuan  ['Q6581072']
# 4403                     Marya Krasińska  ['Q6581072']
# 4794                      Newman Knowlys  ['Q6581097']
# 4814                          Nick Peros  ['Q6581097']
# 4898                       Nun of Watton  ['Q6581072']
# 5080                        Paul Sellers  ['Q6581097']
# 5130                      Pete Podgorski  ['Q6581097']
# 5149        Peter Dawson (bass-baritone)  ['Q6581097']
# 5538                      Robert Muldoon  ['Q6581097']
# 5585                          Roger Lane  ['Q6581097']
# 5700               Rǫgnvaldr Guðrøðarson  ['Q6581097']
# 5746                    Sampoornesh Babu  ['Q6581097']
# 6053                     Stanley Porteus  ['Q6581097']
# 6732              William Goodsir-Cullen  ['Q6581097']
# 6909                            Zhu Hong  ['Q6581097']
# 7201                         Alfred Boyd  ['Q6581097']
# 7484                 Arthur Defensor Sr.  ['Q6581097']
# 7566                   Baker Abdel Munem  ['Q6581097']
# 7655                        Bernd Franke  ['Q6581097']
# 7664                      Bernie Sanders  ['Q6581097']
# 8347                       David Derodon  ['Q6581097']
# 8424                       Deng Xiaoping  ['Q6581097']
# 8441                             Derebey  ['Q6581097']
# 8640              Edward Willis Redfield  ['Q6581097']
# 8914                 Francesco Borromini  ['Q6581097']
# 9148                      George Gerbner  ['Q6581097']
# 10327  John Murray (Australian explorer)  ['Q6581097']
# 11075                       Lucille Kahn  ['Q6581072']
# 11098                       Luis Zuloaga  ['Q6581097']
# 11196                      Manuel Peláez  ['Q6581097']
# 11742       Nathaniel Rogers (physician)  ['Q6581097']
# 11749                      Nawang Sherpa  ['Q6581097']
# 12287                  Raffaele Garrucci  ['Q6581097']
# 12331                    Raoul de Boigne  ['Q6581097']
# 13572                      Walter Maioli  ['Q6581097']
#
#                                               occupation  \
# 745                                        ['Q10871364']
# 900    ['Q188094', 'Q82955', 'Q193391', 'Q806798', 'Q...
# 1916                                          ['Q82955']
# 1973                                          ['Q47064']
# 1999                                       ['Q12299841']
# 2276                           ['Q2374149', 'Q15839134']
# 2384                                          ['Q82955']
# 2558                                                  []
# 2611                              ['Q1930187', 'Q49757']
# 2868               ['Q1238570', 'Q2306091', 'Q18351723']
# 3125                                         ['Q189290']
# 3290                                         ['Q188094']
# 3463                                        ['Q3400985']
# 3941                                         ['Q620175']
# 4099                                          ['Q82955']
# 4403                                                  []
# 4794                                                  []
# 4814                                          ['Q36834']
# 4898                                         ['Q191808']
# 5080                                         ['Q326358']
# 5130                                       ['Q11338576']
# 5149                             ['Q2865819', 'Q753110']
# 5538                                          ['Q82955']
# 5585                                         ['Q201788']
# 5700                                        ['Q2304859']
# 5746                                          ['Q33999']
# 6053                             ['Q1607826', 'Q212980']
# 6732                                       ['Q10843263']
# 6909                                          ['Q36180']
# 7201                                ['Q82955', 'Q43845']
# 7484                                ['Q82955', 'Q40348']
# 7566                                         ['Q193391']
# 7655                                         ['Q937857']
# 7664   ['Q82955', 'Q1930187', 'Q154549', 'Q1622272', ...
# 8347                            ['Q4964182', 'Q1234713']
# 8424                   ['Q82955', 'Q1930187', 'Q193391']
# 8441                                                  []
# 8640                                        ['Q1028181']
# 8914                    ['Q42973', 'Q1281618', 'Q81096']
# 9148   ['Q36180', 'Q215279', 'Q2306091', 'Q1622272', ...
# 10327                                      ['Q11900058']
# 11075                             ['Q33999', 'Q2259451']
# 11098                                      ['Q10871364']
# 11196                               ['Q82955', 'Q47064']
# 11742                                         ['Q39631']
# 11749                                       ['Q9149093']
# 12287               ['Q2004963', 'Q3621491', 'Q1792450']
# 12331                                      ['Q17486376']
# 13572    ['Q4773904', 'Q36834', 'Q3621491', 'Q14915627']
#
#                                                 overview  \
# 745    William Joseph Moisan, Jr. (July 30, 1925 – Ap...
# 900    Béla vitéz Imrédy de Ómoravicza (; 29 December...
# 1916   Felix Magalela Mafa Sibanda born February 5, 1...
# 1973   Francis Fagan was a captain in the United Stat...
# 1999   Frank Rowbotham Foster (31 January 1889 – 3 Ma...
# 2276   Sir Ghillean Tolmie Prance  (born 13 July 1937...
# 2384   Greg Gogan is a Canadian politician and busine...
# 2558   Helen Barrett Tenney worked for the Comintern ...
# 2611   Henryk Jasiczek (2 March 1919 – 8 December 197...
# 2868   Jack A. Goldstone (born September 30, 1953) is...
# 3125   Jeffrey Harbeson is a retired United States Na...
# 3290   John Augustine Ryan (May 25, 1869&nbsp;– Septe...
# 3463   John William Ward (1922&ndash;1985), was a pro...
# 3941   Lawrence (Wawrzyniec) Anthony Wnuk,  (August 6...
# 4099   Lu Lingxuan (陸令萱) (died 577) was a lady in wai...
# 4403   Graciosa Maria "Marya" Krasińska (1854-1884), ...
# 4794   Newman Knowlys (1758&ndash; 5 January 1836) wa...
# 4814   Nick Peros (born March 17, 1963) is a Canadian...
# 4898   Nun of Watton (born in the 1140s) was the prot...
# 5080   Paul Sellers (born 1950) is a British woodwork...
# 5130   Pete Podgorski (born December 1953) is a forme...
# 5149   Peter Smith Dawson (31 January 188227 Septembe...
# 5538   Sir Robert David Muldoon 5 August 1992), also ...
# 5585   Roger Lane is an American historian, and Profe...
# 5700   Rǫgnvaldr Guðrøðarson (died 14 February 1229) ...
# 5746   Sampoornesh Babu is an Indian film actor who w...
# 6053   Prof. Stanley David Porteus (April 24, 1883 - ...
# 6732   William "Willie" James Goodsir-Cullen (29 Marc...
# 6909   Zhu Hong (; 1535–1615) Chinese Buddhist leader...
# 7201   Alfred Boyd (September 20, 1835 &ndash; August...
# 7484   Arthur Doligosa Defensor Sr.  (born December 2...
# 7566   Baker Abdel Munem (, born 1942) was the Palest...
# 7655   Bernd Franke (born 12 February 1948) is a Germ...
# 7664   Bernard<!--Please see: WP:QUOTENAME before pla...
# 8347   David de Rodon or plain Derodon (c. 1600 &ndas...
# 8424   Party Commission: <br>28 June 1981 – 9 Novembe...
# 8441   derebey () was a feudal lord in Anatolia and t...
# 8640   Edward Willis Redfield (December 18, 1869 &nda...
# 8914   Francesco Borromini (, who, with his contempor...
# 9148   George Gerbner (August 8, 1919 – December 24, ...
# 10327  John Murray (c.1775&ndash;c.1807) was a seaman...
# 11075  Lucille Kahn (1902–1995) was a successful Broa...
# 11098  Luis Zuloaga (December 31, 1922 – May 23, 2013...
# 11196  Manuel Peláez Gorrochotegui (1885&ndash;1959) ...
# 11742  Nathaniel Rogers M.D. (1808 – 27 October 1884)...
# 11749  Nawang Sherpa became the first person to climb...
# 12287  Raffaele Garrucci (22 January 1812 – 5 May 188...
# 12331  Raoul Marie Joseph Count de Boigne (25 Decembe...
# 13572  Walter Maioli  (born 1950 in Milan) is an Ital...
#
#                                               adjectives
# 745    [left, handed, right, handed, interested, majo...
# 900    [catholic, young, skilled, fascist, ambitious,...
# 1916   [provincial, inner, great, great, personal, el...
# 1973   [9th, 3rd, second, extraordinary, japanese, st...
# 1999   [short, early, sufficient, fine, round, fast, ...
# 2276   [prominent, british, |, |, major, pmid, |, ghi...
# 2384   [canadian, early, political, private, politica...
# 2558   [comintern, knowledgeable, foreign, late, span...
# 2611   [polish, important, polish, popular, local, po...
# 2868   [american, political, social, political, long,...
# 3125   [notable, human, |archive, human, |archive, ne...
# 3290   [leading, catholic, moral, social, decisive, c...
# 3463   [fourteenth, nonviolent, civil, married, centr...
# 3941   [polish, roman, catholic, catholic, patriotic,...
# 4099   [chinese, wet, powerful, wet, intelligent, dev...
# 4403   [polish, noble, controversial, polish, royal, ...
# 4794   [english, fourth, second, senior, permanent, s...
# 4814   [canadian, classical, extensive, orchestral, c...
# 4898   [twelfth, successful, early, low, religious, s...
# 5080   [british, large, industrial, considerable, wor...
# 5130   [professional, national, polish, russian, iris...
# 5149   [australian, good, operatic, great, contempora...
# 5538   [31st, corporal, qualified, general, decisive,...
# 5585   [american, prestigious, modern, urban, 19th, c...
# 5700   [eld, young, half, military, disaffected, shor...
# 5746   [indian, lead, comedic, innovative, bad, possi...
# 6053   [australian, mixed, initial, feeble, minded, e...
# 6732   [indian, indian, young, unknown, great, indian...
# 6909   [chinese, buddhist, anti, -, excellent, offici...
# 7201   [real, modern, official, parliamentary, recent...
# 7484   [3rd, 14th, sixth, married, chief, overwhelmin...
# 7566   [official, british, arab, israeli, mechanical,...
# 7655   [german, young, professional, young, decent, r...
# 7664   [american, junior, large, congressional, democ...
# 8347   [plain, french, eminent, extensive, profound, ...
# 8424   [term_start2, minister|, predecessor4, collaps...
# 8441   [feudal, pontic, 18th, considerable, central, ...
# 8640   [american, impressionist, local, artistic, ear...
# 8914   [leading, roman, keen, inventive, distinctive,...
# 9148   [jewish, early, assistant, financial, doctorat...
# 10327  [naval, able, second, southern, dangerous, con...
# 11075  [successful, notable, human, close, early, fam...
# 11098  [venezuelan, professional, left, handed, inaug...
# 11196  [mexican, military, noteworthy, coastal, indep...
# 11742  [early, semi, -, stained, anglican, medical, r...
# 11749  [prosthetic, disabled, trans, -, tibial, himal...
# 12287  [christian, wealthy, christian, celebrated, pr...
# 12331  [french, France.;1906, silver, free, seventh, ...
# 13572  [italian, paleorganologist, experimental, part...

# %% [markdown]
# ### Tokenization

# %%
doc = nlp(overview)

#strings are encoded to hashes
tokens = [token.text for token in doc]

tokens[:10]

# %% [markdown]
# ### Removing stop words

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %%
non_stop_words_tokens = [token for token in doc if not token.is_stop]

non_stop_words_tokens[:10]

# %% [markdown]
# ### PoS tagging

# %%
pos_tagged = [(token.text, token.pos_) for token in non_stop_words_tokens]

pos_tagged[:5]

# %%
adjectives = [token[0] for token in pos_tagged if token[1] == 'ADJ']

adjectives[:5]

# %%
words = [token.lemma_ for token in doc if is_adjective(token)]

# %%
words

# %%
from collections import Counter

# five most common tokens
word_freq = Counter(words)
common_words = word_freq.most_common()

print(common_words)

# %% [markdown]
# ## DICTIONARY

# %%
subjectivity_lexicon = {}

# %%
with open("data/subjectivity_lexicon.tff", "r") as file:
    for line in file:
        elements = line.split(" ")
        word = elements[2][6:]
        subjectivity_lexicon[word] = (elements[0][5:], elements[5][14:-1])

# %%
subjectivity_lexicon
# Out:
# {'abandoned': ('weaksubj', 'negative'),
#  'abandonment': ('weaksubj', 'negative'),
#  'abandon': ('weaksubj', 'negative'),
#  'abase': ('strongsubj', 'negative'),
#  'abasement': ('strongsubj', 'negative'),
#  'abash': ('strongsubj', 'negative'),
#  'abate': ('weaksubj', 'negative'),
#  'abdicate': ('weaksubj', 'negative'),
#  'aberration': ('strongsubj', 'negative'),
#  'abhor': ('strongsubj', 'negative'),
#  'abhorred': ('strongsubj', 'negative'),
#  'abhorrence': ('strongsubj', 'negative'),
#  'abhorrent': ('strongsubj', 'negative'),
#  'abhorrently': ('strongsubj', 'negative'),
#  'abhors': ('strongsubj', 'negative'),
#  'abidance': ('strongsubj', 'positive'),
#  'abide': ('strongsubj', 'positive'),
#  'abject': ('strongsubj', 'negative'),
#  'abjectly': ('strongsubj', 'negative'),
#  'abjure': ('weaksubj', 'negative'),
#  'abilities': ('weaksubj', 'positive'),
#  'ability': ('weaksubj', 'positive'),
#  'able': ('weaksubj', 'positive'),
#  'abnormal': ('weaksubj', 'negative'),
#  'abolish': ('weaksubj', 'negative'),
#  'abominable': ('strongsubj', 'negative'),
#  'abominably': ('strongsubj', 'negative'),
#  'abominate': ('strongsubj', 'negative'),
#  'abomination': ('strongsubj', 'negative'),
#  'above': ('weaksubj', 'positive'),
#  'above-average': ('weaksubj', 'positive'),
#  'abound': ('weaksubj', 'positive'),
#  'abrade': ('weaksubj', 'negative'),
#  'abrasive': ('strongsubj', 'negative'),
#  'abrupt': ('weaksubj', 'negative'),
#  'abscond': ('strongsubj', 'negative'),
#  'absence': ('weaksubj', 'negative'),
#  'absentee': ('weaksubj', 'negative'),
#  'absent-minded': ('strongsubj', 'negative'),
#  'absolve': ('strongsubj', 'positive'),
#  'absolute': ('strongsubj', 'neutral'),
#  'absolutely': ('strongsubj', 'neutral'),
#  'absorbed': ('weaksubj', 'neutral'),
#  'absurd': ('strongsubj', 'negative'),
#  'absurdity': ('strongsubj', 'negative'),
#  'absurdly': ('strongsubj', 'negative'),
#  'absurdness': ('strongsubj', 'negative'),
#  'abundant': ('weaksubj', 'positive'),
#  'abundance': ('weaksubj', 'positive'),
#  'abuse': ('strongsubj', 'negative'),
#  'abuses': ('weaksubj', 'negative'),
#  'abusive': ('strongsubj', 'negative'),
#  'abysmal': ('strongsubj', 'negative'),
#  'abysmally': ('strongsubj', 'negative'),
#  'abyss': ('strongsubj', 'negative'),
#  'accede': ('strongsubj', 'positive'),
#  'accentuate': ('strongsubj', 'neutral'),
#  'accept': ('weaksubj', 'positive'),
#  'acceptance': ('weaksubj', 'positive'),
#  'acceptable': ('weaksubj', 'positive'),
#  'accessible': ('weaksubj', 'positive'),
#  'accidental': ('weaksubj', 'negative'),
#  'acclaim': ('strongsubj', 'positive'),
#  'acclaimed': ('strongsubj', 'positive'),
#  'acclamation': ('strongsubj', 'positive'),
#  'accolade': ('strongsubj', 'positive'),
#  'accolades': ('strongsubj', 'positive'),
#  'accommodative': ('weaksubj', 'positive'),
#  'accomplish': ('weaksubj', 'positive'),
#  'accomplishment': ('weaksubj', 'positive'),
#  'accomplishments': ('weaksubj', 'positive'),
#  'accord': ('weaksubj', 'positive'),
#  'accordance': ('weaksubj', 'positive'),
#  'accordantly': ('weaksubj', 'positive'),
#  'accost': ('weaksubj', 'negative'),
#  'accountable': ('weaksubj', 'negative'),
#  'accurate': ('weaksubj', 'positive'),
#  'accurately': ('weaksubj', 'positive'),
#  'accursed': ('strongsubj', 'negative'),
#  'accusation': ('strongsubj', 'negative'),
#  'accusations': ('strongsubj', 'negative'),
#  'accuse': ('strongsubj', 'negative'),
#  'accuses': ('strongsubj', 'negative'),
#  'accusing': ('strongsubj', 'negative'),
#  'accusingly': ('strongsubj', 'negative'),
#  'acerbate': ('strongsubj', 'negative'),
#  'acerbic': ('strongsubj', 'negative'),
#  'acerbically': ('strongsubj', 'negative'),
#  'ache': ('strongsubj', 'negative'),
#  'achievable': ('weaksubj', 'positive'),
#  'achieve': ('weaksubj', 'positive'),
#  'achievement': ('weaksubj', 'positive'),
#  'achievements': ('weaksubj', 'positive'),
#  'acknowledge': ('weaksubj', 'positive'),
#  'acknowledgement': ('weaksubj', 'positive'),
#  'acquit': ('weaksubj', 'positive'),
#  'acrid': ('strongsubj', 'negative'),
#  'acridly': ('strongsubj', 'negative'),
#  'acridness': ('strongsubj', 'negative'),
#  'acrimonious': ('strongsubj', 'negative'),
#  'acrimoniously': ('strongsubj', 'negative'),
#  'acrimony': ('strongsubj', 'negative'),
#  'active': ('weaksubj', 'positive'),
#  'activist': ('strongsubj', 'neutral'),
#  'actual': ('strongsubj', 'neutral'),
#  'actuality': ('strongsubj', 'neutral'),
#  'actually': ('strongsubj', 'neutral'),
#  'acumen': ('strongsubj', 'positive'),
#  'adamant': ('strongsubj', 'negative'),
#  'adamantly': ('strongsubj', 'negative'),
#  'adaptable': ('weaksubj', 'positive'),
#  'adaptability': ('weaksubj', 'positive'),
#  'adaptive': ('weaksubj', 'positive'),
#  'addict': ('weaksubj', 'negative'),
#  'addiction': ('weaksubj', 'negative'),
#  'adept': ('weaksubj', 'positive'),
#  'adeptly': ('weaksubj', 'positive'),
#  'adequate': ('weaksubj', 'positive'),
#  'adherence': ('weaksubj', 'positive'),
#  'adherent': ('weaksubj', 'positive'),
#  'adhesion': ('weaksubj', 'positive'),
#  'admirable': ('strongsubj', 'positive'),
#  'admirer': ('strongsubj', 'positive'),
#  'admirably': ('strongsubj', 'positive'),
#  'admiration': ('strongsubj', 'positive'),
#  'admire': ('strongsubj', 'positive'),
#  'admiring': ('strongsubj', 'positive'),
#  'admiringly': ('strongsubj', 'positive'),
#  'admission': ('weaksubj', 'positive'),
#  'admit': ('strongsubj', 'positive'),
#  'admittedly': ('strongsubj', 'positive'),
#  'admonish': ('strongsubj', 'negative'),
#  'admonisher': ('strongsubj', 'negative'),
#  'admonishingly': ('strongsubj', 'negative'),
#  'admonishment': ('strongsubj', 'negative'),
#  'admonition': ('strongsubj', 'negative'),
#  'adolescents': ('strongsubj', 'neutral'),
#  'adorable': ('strongsubj', 'positive'),
#  'adore': ('strongsubj', 'positive'),
#  'adored': ('strongsubj', 'positive'),
#  'adorer': ('strongsubj', 'positive'),
#  'adoring': ('strongsubj', 'positive'),
#  'adoringly': ('strongsubj', 'positive'),
#  'adrift': ('weaksubj', 'negative'),
#  'adroit': ('strongsubj', 'positive'),
#  'adroitly': ('strongsubj', 'positive'),
#  'adulate': ('strongsubj', 'positive'),
#  'adulation': ('strongsubj', 'positive'),
#  'adulatory': ('strongsubj', 'positive'),
#  'adulterate': ('strongsubj', 'negative'),
#  'adulterated': ('strongsubj', 'negative'),
#  'adulteration': ('strongsubj', 'negative'),
#  'advanced': ('weaksubj', 'positive'),
#  'advantage': ('weaksubj', 'positive'),
#  'advantageous': ('strongsubj', 'positive'),
#  'advantages': ('weaksubj', 'positive'),
#  'adventure': ('weaksubj', 'positive'),
#  'adventuresome': ('strongsubj', 'positive'),
#  'adventurism': ('strongsubj', 'positive'),
#  'adventurous': ('weaksubj', 'positive'),
#  'adversarial': ('weaksubj', 'negative'),
#  'adversary': ('weaksubj', 'negative'),
#  'adverse': ('weaksubj', 'negative'),
#  'adversity': ('strongsubj', 'negative'),
#  'advice': ('weaksubj', 'positive'),
#  'advisable': ('weaksubj', 'positive'),
#  'advocate': ('strongsubj', 'positive'),
#  'advocacy': ('strongsubj', 'positive'),
#  'affable': ('strongsubj', 'positive'),
#  'affability': ('weaksubj', 'positive'),
#  'affably': ('weaksubj', 'positive'),
#  'affect': ('weaksubj', 'neutral'),
#  'affectation': ('weaksubj', 'negative'),
#  'affected': ('strongsubj', 'neutral'),
#  'affection': ('strongsubj', 'positive'),
#  'affectionate': ('strongsubj', 'positive'),
#  'affinity': ('weaksubj', 'positive'),
#  'affirm': ('strongsubj', 'positive'),
#  'affirmation': ('strongsubj', 'positive'),
#  'affirmative': ('weaksubj', 'positive'),
#  'afflict': ('weaksubj', 'negative'),
#  'affliction': ('weaksubj', 'negative'),
#  'afflictive': ('strongsubj', 'negative'),
#  'affluent': ('weaksubj', 'positive'),
#  'affluence': ('weaksubj', 'positive'),
#  'afford': ('weaksubj', 'positive'),
#  'affordable': ('weaksubj', 'positive'),
#  'affront': ('strongsubj', 'negative'),
#  'afloat': ('weaksubj', 'positive'),
#  'afraid': ('strongsubj', 'negative'),
#  'against': ('weaksubj', 'negative'),
#  'aggravate': ('strongsubj', 'negative'),
#  'aggravating': ('strongsubj', 'negative'),
#  'aggravation': ('strongsubj', 'negative'),
#  'aggression': ('strongsubj', 'negative'),
#  'aggressive': ('strongsubj', 'negative'),
#  'aggressiveness': ('strongsubj', 'negative'),
#  'aggressor': ('strongsubj', 'negative'),
#  'aggrieve': ('strongsubj', 'negative'),
#  'aggrieved': ('strongsubj', 'negative'),
#  'aghast': ('strongsubj', 'negative'),
#  'agile': ('weaksubj', 'positive'),
#  'agilely': ('weaksubj', 'positive'),
#  'agility': ('weaksubj', 'positive'),
#  'agitate': ('strongsubj', 'negative'),
#  'agitated': ('strongsubj', 'negative'),
#  'agitation': ('strongsubj', 'negative'),
#  'agitator': ('strongsubj', 'negative'),
#  'agonies': ('strongsubj', 'negative'),
#  'agonize': ('strongsubj', 'negative'),
#  'agonizing': ('strongsubj', 'negative'),
#  'agonizingly': ('strongsubj', 'negative'),
#  'agony': ('strongsubj', 'negative'),
#  'agree': ('strongsubj', 'positive'),
#  'agreeability': ('strongsubj', 'positive'),
#  'agreeable': ('strongsubj', 'positive'),
#  'agreeableness': ('strongsubj', 'positive'),
#  'agreeably': ('strongsubj', 'positive'),
#  'agreement': ('weaksubj', 'positive'),
#  'aha': ('strongsubj', 'neutral'),
#  'ail': ('weaksubj', 'negative'),
#  'ailment': ('weaksubj', 'negative'),
#  'aimless': ('strongsubj', 'negative'),
#  'air': ('strongsubj', 'neutral'),
#  'airs': ('weaksubj', 'negative'),
#  'alarm': ('weaksubj', 'negative'),
#  'alarmed': ('strongsubj', 'negative'),
#  'alarming': ('strongsubj', 'negative'),
#  'alarmingly': ('strongsubj', 'negative'),
#  'alas': ('strongsubj', 'negative'),
#  'alert': ('weaksubj', 'neutral'),
#  'alienate': ('weaksubj', 'negative'),
#  'alienated': ('weaksubj', 'negative'),
#  'alienation': ('weaksubj', 'negative'),
#  'all-time': ('weaksubj', 'neutral'),
#  'allay': ('strongsubj', 'positive'),
#  'allegation': ('strongsubj', 'negative'),
#  'allegations': ('strongsubj', 'negative'),
#  'allege': ('weaksubj', 'negative'),
#  'allegorize': ('strongsubj', 'neutral'),
#  'allergic': ('weaksubj', 'negative'),
#  'alleviate': ('weaksubj', 'positive'),
#  'alliance': ('strongsubj', 'neutral'),
#  'alliances': ('strongsubj', 'neutral'),
#  'allow': ('weaksubj', 'positive'),
#  'allowable': ('weaksubj', 'positive'),
#  'allure': ('strongsubj', 'positive'),
#  'alluring': ('strongsubj', 'positive'),
#  'alluringly': ('strongsubj', 'positive'),
#  'allusion': ('strongsubj', 'neutral'),
#  'allusions': ('strongsubj', 'neutral'),
#  'ally': ('strongsubj', 'positive'),
#  'almighty': ('strongsubj', 'positive'),
#  'aloof': ('strongsubj', 'negative'),
#  'altercation': ('weaksubj', 'negative'),
#  'although': ('weaksubj', 'negative'),
#  'altogether': ('strongsubj', 'neutral'),
#  'altruist': ('strongsubj', 'positive'),
#  'altruistic': ('strongsubj', 'positive'),
#  'altruistically': ('strongsubj', 'positive'),
#  'amaze': ('strongsubj', 'positive'),
#  'amazed': ('strongsubj', 'positive'),
#  'amazement': ('strongsubj', 'positive'),
#  'amazing': ('strongsubj', 'positive'),
#  'amazingly': ('strongsubj', 'positive'),
#  'ambiguous': ('strongsubj', 'negative'),
#  'ambiguity': ('strongsubj', 'negative'),
#  'ambitious': ('weaksubj', 'positive'),
#  'ambitiously': ('weaksubj', 'positive'),
#  'ambivalence': ('strongsubj', 'negative'),
#  'ambivalent': ('strongsubj', 'negative'),
#  'ambush': ('weaksubj', 'negative'),
#  'ameliorate': ('strongsubj', 'positive'),
#  'amenable': ('strongsubj', 'positive'),
#  'amenity': ('weaksubj', 'positive'),
#  'amiability': ('strongsubj', 'positive'),
#  'amiabily': ('strongsubj', 'positive'),
#  'amiable': ('strongsubj', 'positive'),
#  'amicability': ('strongsubj', 'positive'),
#  'amicable': ('strongsubj', 'positive'),
#  'amicably': ('strongsubj', 'positive'),
#  'amiss': ('strongsubj', 'negative'),
#  'amity': ('weaksubj', 'positive'),
#  'amnesty': ('weaksubj', 'positive'),
#  'amour': ('strongsubj', 'positive'),
#  'ample': ('weaksubj', 'positive'),
#  'amply': ('weaksubj', 'positive'),
#  'amplify': ('weaksubj', 'neutral'),
#  'amputate': ('weaksubj', 'negative'),
#  'amuse': ('strongsubj', 'positive'),
#  'amusement': ('strongsubj', 'positive'),
#  'amusing': ('strongsubj', 'positive'),
#  'amusingly': ('strongsubj', 'positive'),
#  'analytical': ('weaksubj', 'neutral'),
#  'anarchism': ('strongsubj', 'negative'),
#  'anarchist': ('strongsubj', 'negative'),
#  'anarchistic': ('strongsubj', 'negative'),
#  'anarchy': ('strongsubj', 'negative'),
#  'anemic': ('weaksubj', 'negative'),
#  'angel': ('weaksubj', 'positive'),
#  'angelic': ('strongsubj', 'positive'),
#  'anger': ('strongsubj', 'negative'),
#  'angrily': ('strongsubj', 'negative'),
#  'angriness': ('strongsubj', 'negative'),
#  'angry': ('strongsubj', 'negative'),
#  'anguish': ('strongsubj', 'negative'),
#  'annihilate': ('strongsubj', 'negative'),
#  'annihilation': ('strongsubj', 'negative'),
#  'animated': ('weaksubj', 'positive'),
#  'animosity': ('strongsubj', 'negative'),
#  'annoy': ('strongsubj', 'negative'),
#  'annoyance': ('strongsubj', 'negative'),
#  'annoyed': ('strongsubj', 'negative'),
#  'annoying': ('strongsubj', 'negative'),
#  'annoyingly': ('strongsubj', 'negative'),
#  'anomalous': ('weaksubj', 'negative'),
#  'anomaly': ('weaksubj', 'negative'),
#  'antagonism': ('strongsubj', 'negative'),
#  'antagonist': ('weaksubj', 'negative'),
#  'antagonistic': ('strongsubj', 'negative'),
#  'antagonize': ('strongsubj', 'negative'),
#  'anti-': ('strongsubj', 'negative'),
#  'anti-American': ('strongsubj', 'negative'),
#  'anti-Israeli': ('strongsubj', 'negative'),
#  'anti-Semites': ('strongsubj', 'negative'),
#  'anti-US': ('strongsubj', 'negative'),
#  'anti-occupation': ('strongsubj', 'negative'),
#  'anti-proliferation': ('strongsubj', 'negative'),
#  'anti-social': ('strongsubj', 'negative'),
#  'anti-white': ('strongsubj', 'negative'),
#  'antipathy': ('strongsubj', 'negative'),
#  'antiquated': ('strongsubj', 'negative'),
#  'antithetical': ('strongsubj', 'negative'),
#  'anxieties': ('strongsubj', 'negative'),
#  'anxiety': ('strongsubj', 'negative'),
#  'anxious': ('strongsubj', 'negative'),
#  'anxiously': ('strongsubj', 'negative'),
#  'anxiousness': ('strongsubj', 'negative'),
#  'anyhow': ('strongsubj', 'neutral'),
#  'anyway': ('strongsubj', 'neutral'),
#  'anyways': ('strongsubj', 'neutral'),
#  'apathetic': ('strongsubj', 'negative'),
#  'apathetically': ('strongsubj', 'negative'),
#  'apathy': ('strongsubj', 'negative'),
#  'ape': ('strongsubj', 'negative'),
#  'apocalypse': ('strongsubj', 'negative'),
#  'apocalyptic': ('strongsubj', 'negative'),
#  'apologist': ('strongsubj', 'negative'),
#  'apologists': ('strongsubj', 'negative'),
#  'apostle': ('strongsubj', 'positive'),
#  'apotheosis': ('strongsubj', 'positive'),
#  'appal': ('strongsubj', 'negative'),
#  'appall': ('strongsubj', 'negative'),
#  'appalled': ('strongsubj', 'negative'),
#  'appalling': ('strongsubj', 'negative'),
#  'appallingly': ('strongsubj', 'negative'),
#  'apparent': ('weaksubj', 'neutral'),
#  'apparently': ('weaksubj', 'neutral'),
#  'appeal': ('weaksubj', 'positive'),
#  'appealing': ('strongsubj', 'positive'),
#  'appear': ('weaksubj', 'neutral'),
#  'appearance': ('weaksubj', 'neutral'),
#  'appease': ('weaksubj', 'positive'),
#  'applaud': ('strongsubj', 'positive'),
#  'appreciable': ('weaksubj', 'positive'),
#  'appreciate': ('strongsubj', 'positive'),
#  'appreciation': ('strongsubj', 'positive'),
#  'appreciative': ('strongsubj', 'positive'),
#  'appreciatively': ('strongsubj', 'positive'),
#  'appreciativeness': ('strongsubj', 'positive'),
#  'apprehend': ('weaksubj', 'neutral'),
#  'apprehension': ('strongsubj', 'negative'),
#  'apprehensions': ('strongsubj', 'negative'),
#  'apprehensive': ('strongsubj', 'negative'),
#  'apprehensively': ('strongsubj', 'negative'),
#  'appropriate': ('weaksubj', 'positive'),
#  'approval': ('weaksubj', 'positive'),
#  'approve': ('weaksubj', 'positive'),
#  'apt': ('weaksubj', 'positive'),
#  'aptly': ('weaksubj', 'positive'),
#  'aptitude': ('weaksubj', 'positive'),
#  'arbitrary': ('strongsubj', 'negative'),
#  'arcane': ('strongsubj', 'negative'),
#  'archaic': ('strongsubj', 'negative'),
#  'ardent': ('strongsubj', 'positive'),
#  'ardently': ('strongsubj', 'positive'),
#  'ardor': ('strongsubj', 'positive'),
#  'arduous': ('strongsubj', 'negative'),
#  'arduously': ('strongsubj', 'negative'),
#  'aristocratic': ('weaksubj', 'positive'),
#  'argue': ('strongsubj', 'negative'),
#  'argument': ('weaksubj', 'negative'),
#  'argumentative': ('strongsubj', 'negative'),
#  'arguments': ('weaksubj', 'negative'),
#  'arousal': ('strongsubj', 'positive'),
#  'arouse': ('strongsubj', 'positive'),
#  'arousing': ('strongsubj', 'positive'),
#  'arresting': ('strongsubj', 'positive'),
#  'arrogance': ('strongsubj', 'negative'),
#  'arrogant': ('strongsubj', 'negative'),
#  'arrogantly': ('strongsubj', 'negative'),
#  'articulate': ('strongsubj', 'positive'),
#  'artificial': ('weaksubj', 'negative'),
#  'ascendant': ('strongsubj', 'positive'),
#  'ascertainable': ('strongsubj', 'positive'),
#  'ashamed': ('strongsubj', 'negative'),
#  'asinine': ('strongsubj', 'negative'),
#  'asininely': ('strongsubj', 'negative'),
#  'asinininity': ('strongsubj', 'negative'),
#  'askance': ('strongsubj', 'negative'),
#  'asperse': ('strongsubj', 'negative'),
#  'aspersion': ('strongsubj', 'negative'),
#  'aspersions': ('strongsubj', 'negative'),
#  'aspiration': ('strongsubj', 'positive'),
#  'aspirations': ('strongsubj', 'positive'),
#  'aspire': ('strongsubj', 'positive'),
#  'assail': ('weaksubj', 'negative'),
#  'assassinate': ('weaksubj', 'negative'),
#  'assassin': ('strongsubj', 'negative'),
#  'assault': ('weaksubj', 'negative'),
#  'assent': ('strongsubj', 'positive'),
#  'assertions': ('strongsubj', 'positive'),
#  'assertive': ('weaksubj', 'positive'),
#  'assess': ('strongsubj', 'neutral'),
#  'assessment': ('weaksubj', 'neutral'),
#  'assessments': ('weaksubj', 'neutral'),
#  'asset': ('weaksubj', 'positive'),
#  'assiduous': ('strongsubj', 'positive'),
#  'assiduously': ('strongsubj', 'positive'),
#  'assuage': ('weaksubj', 'positive'),
#  'assumption': ('weaksubj', 'neutral'),
#  'assurance': ('weaksubj', 'positive'),
#  'assurances': ('weaksubj', 'positive'),
#  'assure': ('strongsubj', 'positive'),
#  'assuredly': ('strongsubj', 'positive'),
#  'astonish': ('strongsubj', 'positive'),
#  'astonished': ('strongsubj', 'positive'),
#  'astonishing': ('strongsubj', 'positive'),
#  'astonishingly': ('strongsubj', 'positive'),
#  'astonishment': ('strongsubj', 'positive'),
#  'astound': ('strongsubj', 'positive'),
#  'astounded': ('strongsubj', 'positive'),
#  'astounding': ('strongsubj', 'positive'),
#  'astoundingly': ('strongsubj', 'positive'),
#  'astray': ('weaksubj', 'negative'),
#  'astronomic': ('strongsubj', 'neutral'),
#  'astronomical': ('strongsubj', 'neutral'),
#  'astronomically': ('strongsubj', 'neutral'),
#  'astute': ('strongsubj', 'positive'),
#  'astutely': ('strongsubj', 'positive'),
#  'asunder': ('strongsubj', 'negative'),
#  'asylum': ('weaksubj', 'positive'),
#  'atrocious': ('strongsubj', 'negative'),
#  'atrocities': ('strongsubj', 'negative'),
#  'atrocity': ('strongsubj', 'negative'),
#  'atrophy': ('strongsubj', 'negative'),
#  'attack': ('weaksubj', 'negative'),
#  'attain': ('weaksubj', 'positive'),
#  'attainable': ('weaksubj', 'positive'),
#  'attentive': ('strongsubj', 'positive'),
#  'attest': ('strongsubj', 'positive'),
#  'attitude': ('strongsubj', 'neutral'),
#  'attitudes': ('weaksubj', 'neutral'),
#  'attraction': ('strongsubj', 'positive'),
#  'attractive': ('strongsubj', 'positive'),
#  'attractively': ('strongsubj', 'positive'),
#  'attune': ('weaksubj', 'positive'),
#  'audacious': ('strongsubj', 'negative'),
#  'audaciously': ('strongsubj', 'negative'),
#  'audaciousness': ('strongsubj', 'negative'),
#  'audacity': ('strongsubj', 'negative'),
#  'auspicious': ('strongsubj', 'positive'),
#  'austere': ('strongsubj', 'negative'),
#  'authentic': ('weaksubj', 'positive'),
#  'authoritarian': ('weaksubj', 'negative'),
#  'authoritative': ('weaksubj', 'positive'),
#  'autocrat': ('strongsubj', 'negative'),
#  'autocratic': ('strongsubj', 'negative'),
#  'award': ('weaksubj', 'positive'),
#  'awareness': ('strongsubj', 'neutral'),
#  'aware': ('strongsubj', 'neutral'),
#  'autonomous': ('weaksubj', 'positive'),
#  'avalanche': ('strongsubj', 'negative'),
#  'avarice': ('strongsubj', 'negative'),
#  'avaricious': ('strongsubj', 'negative'),
#  'avariciously': ('strongsubj', 'negative'),
#  'avenge': ('strongsubj', 'negative'),
#  'aver': ('strongsubj', 'positive'),
#  'averse': ('strongsubj', 'negative'),
#  'aversion': ('strongsubj', 'negative'),
#  'avid': ('strongsubj', 'positive'),
#  'avidly': ('strongsubj', 'positive'),
#  'avoid': ('weaksubj', 'negative'),
#  'avoidance': ('weaksubj', 'negative'),
#  'awe': ('strongsubj', 'positive'),
#  'awed': ('strongsubj', 'positive'),
#  'awesome': ('strongsubj', 'positive'),
#  'awesomely': ('strongsubj', 'positive'),
#  'awesomeness': ('strongsubj', 'positive'),
#  'awestruck': ('strongsubj', 'positive'),
#  'awful': ('strongsubj', 'negative'),
#  'awfully': ('strongsubj', 'negative'),
#  'awfulness': ('strongsubj', 'negative'),
#  'awkward': ('strongsubj', 'negative'),
#  'awkwardness': ('strongsubj', 'negative'),
#  'ax': ('strongsubj', 'negative'),
#  'babble': ('strongsubj', 'negative'),
#  'baby': ('strongsubj', 'neutral'),
#  'back': ('weaksubj', 'positive'),
#  'backbite': ('strongsubj', 'negative'),
#  'backbiting': ('strongsubj', 'negative'),
#  'backbone': ('weaksubj', 'positive'),
#  'backward': ('strongsubj', 'negative'),
#  'backwardness': ('strongsubj', 'negative'),
#  'bad': ('strongsubj', 'negative'),
#  'badly': ('strongsubj', 'negative'),
#  'baffle': ('strongsubj', 'negative'),
#  'baffled': ('strongsubj', 'negative'),
#  'bafflement': ('strongsubj', 'negative'),
#  'baffling': ('strongsubj', 'negative'),
#  'bait': ('strongsubj', 'negative'),
#  'balanced': ('weaksubj', 'positive'),
#  'balk': ('strongsubj', 'negative'),
#  'banal': ('strongsubj', 'negative'),
#  'banalize': ('strongsubj', 'negative'),
#  'bane': ('strongsubj', 'negative'),
#  'banish': ('strongsubj', 'negative'),
#  'banishment': ('strongsubj', 'negative'),
#  'bankrupt': ('weaksubj', 'negative'),
#  'bar': ('weaksubj', 'negative'),
#  'barbarian': ('strongsubj', 'negative'),
#  'barbaric': ('strongsubj', 'negative'),
#  'barbarically': ('strongsubj', 'negative'),
#  'barbarity': ('strongsubj', 'negative'),
#  'barbarous': ('strongsubj', 'negative'),
#  'barbarously': ('strongsubj', 'negative'),
#  'barely': ('weaksubj', 'negative'),
#  'bargain': ('strongsubj', 'positive'),
#  'barren': ('strongsubj', 'negative'),
#  'baseless': ('strongsubj', 'negative'),
#  'bashful': ('strongsubj', 'negative'),
#  'basic': ('weaksubj', 'positive'),
#  'basically': ('weaksubj', 'neutral'),
#  'bask': ('weaksubj', 'positive'),
#  'bastard': ('strongsubj', 'negative'),
#  'batons': ('weaksubj', 'neutral'),
#  'battered': ('weaksubj', 'negative'),
#  'battering': ('weaksubj', 'negative'),
#  'battle': ('weaksubj', 'negative'),
#  'battle-lines': ('strongsubj', 'negative'),
#  'battlefield': ('weaksubj', 'negative'),
#  'battleground': ('strongsubj', 'negative'),
#  'batty': ('strongsubj', 'negative'),
#  'beacon': ('weaksubj', 'positive'),
#  'bearish': ('weaksubj', 'negative'),
#  'beast': ('strongsubj', 'negative'),
#  'beastly': ('strongsubj', 'negative'),
#  'beatify': ('strongsubj', 'positive'),
#  'beauteous': ('strongsubj', 'positive'),
#  'beautiful': ('strongsubj', 'positive'),
#  'beautifully': ('strongsubj', 'positive'),
#  'beautify': ('strongsubj', 'positive'),
#  'beauty': ('strongsubj', 'positive'),
#  'bedlam': ('strongsubj', 'negative'),
#  'bedlamite': ('strongsubj', 'negative'),
#  'befit': ('strongsubj', 'positive'),
#  'befitting': ('strongsubj', 'positive'),
#  'befoul': ('strongsubj', 'negative'),
#  'befriend': ('strongsubj', 'positive'),
#  'beg': ('strongsubj', 'negative'),
#  'beggar': ('weaksubj', 'negative'),
#  'beggarly': ('strongsubj', 'negative'),
#  'begging': ('strongsubj', 'negative'),
#  'beguile': ('strongsubj', 'negative'),
#  'belated': ('weaksubj', 'negative'),
#  'belabor': ('strongsubj', 'negative'),
#  'beleaguer': ('strongsubj', 'negative'),
#  'belie': ('strongsubj', 'negative'),
#  'belief': ('strongsubj', 'neutral'),
#  'beliefs': ('weaksubj', 'neutral'),
#  'believable': ('strongsubj', 'positive'),
#  'believe': ('strongsubj', 'neutral'),
#  'belittle': ('strongsubj', 'negative'),
#  'belittled': ('strongsubj', 'negative'),
#  'belittling': ('strongsubj', 'negative'),
#  'bellicose': ('strongsubj', 'negative'),
#  'belligerence': ('strongsubj', 'negative'),
#  'belligerent': ('strongsubj', 'negative'),
#  'belligerently': ('strongsubj', 'negative'),
#  'beloved': ('strongsubj', 'positive'),
#  'bemoan': ('strongsubj', 'negative'),
#  'bemoaning': ('strongsubj', 'negative'),
#  'bemused': ('strongsubj', 'negative'),
#  'benefactor': ('weaksubj', 'positive'),
#  'beneficial': ('strongsubj', 'positive'),
#  'beneficent': ('strongsubj', 'positive'),
#  'beneficially': ('strongsubj', 'positive'),
#  'beneficiary': ('strongsubj', 'positive'),
#  'benefit': ('weaksubj', 'positive'),
#  'benefits': ('weaksubj', 'positive'),
#  'benevolence': ('strongsubj', 'positive'),
#  'benevolent': ('strongsubj', 'positive'),
#  'benign': ('weaksubj', 'positive'),
#  'bent': ('weaksubj', 'negative'),
#  'berate': ('strongsubj', 'negative'),
#  'bereave': ('strongsubj', 'negative'),
#  'bereavement': ('strongsubj', 'negative'),
#  'bereft': ('strongsubj', 'negative'),
#  'berserk': ('strongsubj', 'negative'),
#  'beseech': ('strongsubj', 'negative'),
#  'beset': ('weaksubj', 'negative'),
#  'besides': ('strongsubj', 'neutral'),
#  'besiege': ('weaksubj', 'negative'),
#  'besmirch': ('strongsubj', 'negative'),
#  'best': ('strongsubj', 'positive'),
#  'best-known': ('strongsubj', 'positive'),
#  'best-performing': ('strongsubj', 'positive'),
#  'best-selling': ('weaksubj', 'positive'),
#  'bestial': ('strongsubj', 'negative'),
#  'betray': ('strongsubj', 'negative'),
#  'betrayal': ('strongsubj', 'negative'),
#  'betrayals': ('strongsubj', 'negative'),
#  'betrayer': ('strongsubj', 'negative'),
#  'better': ('weaksubj', 'positive'),
#  'better-known': ('strongsubj', 'positive'),
#  'better-than-expected': ('strongsubj', 'positive'),
#  'bewail': ('strongsubj', 'negative'),
#  'beware': ('weaksubj', 'negative'),
#  'bewilder': ('strongsubj', 'negative'),
#  'bewildered': ('strongsubj', 'negative'),
#  'bewildering': ('strongsubj', 'negative'),
#  'bewilderingly': ('strongsubj', 'negative'),
#  'bewilderment': ('strongsubj', 'negative'),
#  'bewitch': ('strongsubj', 'negative'),
#  'bias': ('strongsubj', 'negative'),
#  'biased': ('strongsubj', 'negative'),
#  'biases': ('strongsubj', 'negative'),
#  'bicker': ('strongsubj', 'negative'),
#  'bickering': ('strongsubj', 'negative'),
#  'bid-rigging': ('weaksubj', 'negative'),
#  'big': ('weaksubj', 'neutral'),
#  'bitch': ('strongsubj', 'negative'),
#  'bitchy': ('strongsubj', 'negative'),
#  'biting': ('strongsubj', 'negative'),
#  'bitingly': ('strongsubj', 'negative'),
#  'bitter': ('strongsubj', 'negative'),
#  'bitterly': ('strongsubj', 'negative'),
#  'bitterness': ('strongsubj', 'negative'),
#  'bizarre': ('strongsubj', 'negative'),
#  'blab': ('strongsubj', 'negative'),
#  'blabber': ('strongsubj', 'negative'),
#  'black': ('weaksubj', 'negative'),
#  'blackmail': ('weaksubj', 'negative'),
#  'blah': ('strongsubj', 'negative'),
#  'blame': ('strongsubj', 'negative'),
#  'blameless': ('strongsubj', 'positive'),
#  'blameworthy': ('strongsubj', 'negative'),
#  'bland': ('strongsubj', 'negative'),
#  'blandish': ('strongsubj', 'negative'),
#  'blaspheme': ('strongsubj', 'negative'),
#  'blasphemous': ('strongsubj', 'negative'),
#  'blasphemy': ('strongsubj', 'negative'),
#  'blast': ('weaksubj', 'negative'),
#  'blasted': ('strongsubj', 'negative'),
#  'blatant': ('strongsubj', 'negative'),
#  'blatantly': ('strongsubj', 'negative'),
#  'blather': ('strongsubj', 'negative'),
#  'bleak': ('strongsubj', 'negative'),
#  'bleakly': ('strongsubj', 'negative'),
#  'bleakness': ('strongsubj', 'negative'),
#  'bleed': ('weaksubj', 'negative'),
#  'blemish': ('weaksubj', 'negative'),
#  'bless': ('strongsubj', 'positive'),
#  'blessing': ('strongsubj', 'positive'),
#  'blind': ('weaksubj', 'negative'),
#  'blinding': ('strongsubj', 'negative'),
#  'blindingly': ('strongsubj', 'negative'),
#  'blindness': ('weaksubj', 'negative'),
#  'blindside': ('strongsubj', 'negative'),
#  'bliss': ('strongsubj', 'positive'),
#  'blissful': ('strongsubj', 'positive'),
#  'blissfully': ('strongsubj', 'positive'),
#  'blister': ('strongsubj', 'negative'),
#  'blistering': ('strongsubj', 'negative'),
#  'blithe': ('strongsubj', 'positive'),
#  'bloated': ('strongsubj', 'negative'),
#  'block': ('weaksubj', 'negative'),
#  'blockhead': ('strongsubj', 'negative'),
#  'blood': ('weaksubj', 'negative'),
#  'bloodshed': ('strongsubj', 'negative'),
#  'bloodthirsty': ('strongsubj', 'negative'),
#  'bloody': ('weaksubj', 'negative'),
#  'bloom': ('weaksubj', 'positive'),
#  'blossom': ('weaksubj', 'positive'),
#  'blow': ('weaksubj', 'negative'),
#  'blunder': ('strongsubj', 'negative'),
#  'blundering': ('strongsubj', 'negative'),
#  'blunders': ('strongsubj', 'negative'),
#  'blunt': ('strongsubj', 'negative'),
#  'blur': ('weaksubj', 'negative'),
#  'blurt': ('strongsubj', 'negative'),
#  'boast': ('strongsubj', 'negative'),
#  'boastful': ('strongsubj', 'negative'),
#  'boggle': ('strongsubj', 'negative'),
#  'bogus': ('strongsubj', 'negative'),
#  'boil': ('strongsubj', 'negative'),
#  'boiling': ('strongsubj', 'negative'),
#  'boisterous': ('strongsubj', 'negative'),
#  'bold': ('strongsubj', 'positive'),
#  'boldly': ('strongsubj', 'positive'),
#  'boldness': ('strongsubj', 'positive'),
#  'bolster': ('strongsubj', 'positive'),
#  'bombard': ('weaksubj', 'negative'),
#  'bomb': ('weaksubj', 'negative'),
#  'bombardment': ('strongsubj', 'negative'),
#  'bombastic': ('strongsubj', 'negative'),
#  'bondage': ('strongsubj', 'negative'),
#  'bonkers': ('strongsubj', 'negative'),
#  'bonny': ('strongsubj', 'positive'),
#  'bonus': ('weaksubj', 'positive'),
#  'boom': ('weaksubj', 'positive'),
#  'booming': ('weaksubj', 'positive'),
#  'boost': ('weaksubj', 'positive'),
#  'bore': ('strongsubj', 'negative'),
#  'boredom': ('strongsubj', 'negative'),
#  'boring': ('strongsubj', 'negative'),
#  'botch': ('strongsubj', 'negative'),
#  'bother': ('strongsubj', 'negative'),
#  'bothersome': ('strongsubj', 'negative'),
#  'boundless': ('strongsubj', 'positive'),
#  'bountiful': ('strongsubj', 'positive'),
#  'bowdlerize': ('strongsubj', 'negative'),
#  'boycott': ('weaksubj', 'negative'),
#  'brag': ('strongsubj', 'both'),
#  'braggart': ('strongsubj', 'negative'),
#  'bragger': ('strongsubj', 'negative'),
#  'brains': ('strongsubj', 'positive'),
#  'brainwash': ('strongsubj', 'negative'),
#  'brainy': ('strongsubj', 'positive'),
#  'brash': ('strongsubj', 'negative'),
#  'brashly': ('strongsubj', 'negative'),
#  'brashness': ('strongsubj', 'negative'),
#  'brat': ('strongsubj', 'negative'),
#  'bravado': ('strongsubj', 'negative'),
#  'brave': ('strongsubj', 'positive'),
#  'bravery': ('strongsubj', 'positive'),
#  'brazen': ('strongsubj', 'negative'),
#  'brazenly': ('strongsubj', 'negative'),
#  'brazenness': ('strongsubj', 'negative'),
#  'breach': ('weaksubj', 'negative'),
#  'break': ('weaksubj', 'negative'),
#  'break-point': ('strongsubj', 'negative'),
#  'breakdown': ('weaksubj', 'negative'),
#  'breakthrough': ('weaksubj', 'positive'),
#  'breakthroughs': ('weaksubj', 'positive'),
#  'breathlessness': ('strongsubj', 'positive'),
#  'breathtaking': ('strongsubj', 'positive'),
#  'breathtakingly': ('strongsubj', 'positive'),
#  'bright': ('weaksubj', 'positive'),
#  'brighten': ('weaksubj', 'positive'),
#  'brightness': ('weaksubj', 'positive'),
#  'brilliance': ('weaksubj', 'positive'),
#  'brilliant': ('strongsubj', 'positive'),
#  'brilliantly': ('strongsubj', 'positive'),
#  'brimstone': ('strongsubj', 'negative'),
#  'brisk': ('weaksubj', 'positive'),
#  'bristle': ('strongsubj', 'negative'),
#  'brittle': ('weaksubj', 'negative'),
#  'broad': ('weaksubj', 'positive'),
#  'broad-based': ('weaksubj', 'neutral'),
#  'broke': ('weaksubj', 'negative'),
#  'broken-hearted': ('strongsubj', 'negative'),
#  'brood': ('strongsubj', 'negative'),
#  'brook': ('strongsubj', 'positive'),
#  'brotherly': ('weaksubj', 'positive'),
#  'browbeat': ('strongsubj', 'negative'),
#  'bruise': ('weaksubj', 'negative'),
#  'brusque': ('strongsubj', 'negative'),
#  'brutal': ('strongsubj', 'negative'),
#  'brutalising': ('strongsubj', 'negative'),
#  'brutalities': ('strongsubj', 'negative'),
#  'brutality': ('strongsubj', 'negative'),
#  'brutalize': ('strongsubj', 'negative'),
#  'brutalizing': ('strongsubj', 'negative'),
#  'brutally': ('strongsubj', 'negative'),
#  'brute': ('strongsubj', 'negative'),
#  'brutish': ('strongsubj', 'negative'),
#  'bug': ('weaksubj', 'negative'),
#  'buckle': ('weaksubj', 'negative'),
#  'bulky': ('weaksubj', 'negative'),
#  'bull': ('weaksubj', 'positive'),
#  'bullies': ('strongsubj', 'negative'),
#  'bullish': ('weaksubj', 'positive'),
#  'bully': ('strongsubj', 'negative'),
#  'bullyingly': ('strongsubj', 'negative'),
#  'bum': ('weaksubj', 'negative'),
#  'bumpy': ('weaksubj', 'negative'),
#  'bungle': ('strongsubj', 'negative'),
#  'bungler': ('strongsubj', 'negative'),
#  'bunk': ('weaksubj', 'negative'),
#  'buoyant': ('weaksubj', 'positive'),
#  'burden': ('strongsubj', 'negative'),
#  'burdensome': ('strongsubj', 'negative'),
#  'burdensomely': ('strongsubj', 'negative'),
#  'burn': ('strongsubj', 'negative'),
#  'busy': ('weaksubj', 'negative'),
#  'busybody': ('strongsubj', 'negative'),
#  'butcher': ('weaksubj', 'negative'),
#  'butchery': ('strongsubj', 'negative'),
#  'byzantine': ('strongsubj', 'negative'),
#  'cackle': ('strongsubj', 'negative'),
#  'cajole': ('strongsubj', 'negative'),
#  'calamities': ('strongsubj', 'negative'),
#  'calamitous': ('strongsubj', 'negative'),
#  'calamitously': ('strongsubj', 'negative'),
#  'calamity': ('strongsubj', 'negative'),
#  'callous': ('strongsubj', 'negative'),
#  'calm': ('weaksubj', 'positive'),
#  'calming': ('strongsubj', 'positive'),
#  'calmness': ('weaksubj', 'positive'),
#  'calumniate': ('strongsubj', 'negative'),
#  'calumniation': ('strongsubj', 'negative'),
#  'calumnies': ('strongsubj', 'negative'),
#  'calumnious': ('strongsubj', 'negative'),
#  'calumniously': ('strongsubj', 'negative'),
#  'calumny': ('strongsubj', 'negative'),
#  'cancer': ('weaksubj', 'negative'),
#  'cancerous': ('weaksubj', 'negative'),
#  'candid': ('strongsubj', 'positive'),
#  'candor': ('strongsubj', 'positive'),
#  'cannibal': ('strongsubj', 'negative'),
#  'cannibalize': ('strongsubj', 'negative'),
#  'capable': ('weaksubj', 'positive'),
#  'capability': ('weaksubj', 'positive'),
#  'capably': ('weaksubj', 'positive'),
#  'capitalize': ('weaksubj', 'positive'),
#  'capitulate': ('weaksubj', 'negative'),
#  'capricious': ('strongsubj', 'negative'),
#  'capriciously': ('strongsubj', 'negative'),
#  'capriciousness': ('strongsubj', 'negative'),
#  'capsize': ('weaksubj', 'negative'),
#  'captivate': ('strongsubj', 'positive'),
#  'captivating': ('strongsubj', 'positive'),
#  'captivation': ('strongsubj', 'positive'),
#  'captive': ('weaksubj', 'negative'),
#  'care': ('weaksubj', 'positive'),
#  'carefree': ('strongsubj', 'positive'),
#  'careful': ('weaksubj', 'positive'),
#  'careless': ('strongsubj', 'negative'),
#  'carelessness': ('strongsubj', 'negative'),
#  'caricature': ('strongsubj', 'negative'),
#  'carnage': ('strongsubj', 'negative'),
#  'carp': ('strongsubj', 'negative'),
#  'cartoon': ('weaksubj', 'negative'),
#  'cartoonish': ('strongsubj', 'negative'),
#  'cash-strapped': ('weaksubj', 'negative'),
#  'castigate': ('strongsubj', 'negative'),
#  'casualty': ('weaksubj', 'negative'),
#  'cataclysm': ('strongsubj', 'negative'),
#  'cataclysmal': ('strongsubj', 'negative'),
#  'cataclysmic': ('strongsubj', 'negative'),
#  'cataclysmically': ('strongsubj', 'negative'),
#  'catalyst': ('strongsubj', 'positive'),
#  'catastrophe': ('strongsubj', 'negative'),
#  'catastrophes': ('strongsubj', 'negative'),
#  'catastrophic': ('strongsubj', 'negative'),
#  'catastrophically': ('strongsubj', 'negative'),
#  'catchy': ('strongsubj', 'positive'),
#  'caustic': ('strongsubj', 'negative'),
#  'caustically': ('strongsubj', 'negative'),
#  'cautionary': ('strongsubj', 'negative'),
#  'cautious': ('weaksubj', 'negative'),
#  'cave': ('weaksubj', 'negative'),
#  'ceaseless': ('weaksubj', 'neutral'),
#  'celebrate': ('strongsubj', 'positive'),
#  'celebrated': ('strongsubj', 'positive'),
#  'celebration': ('strongsubj', 'positive'),
#  'celebratory': ('strongsubj', 'positive'),
#  'celebrity': ('weaksubj', 'positive'),
#  'censure': ('strongsubj', 'negative'),
#  'central': ('weaksubj', 'neutral'),
#  'certain': ('weaksubj', 'neutral'),
#  'certainly': ('strongsubj', 'neutral'),
#  'certified': ('weaksubj', 'neutral'),
#  'chafe': ('strongsubj', 'negative'),
#  'chaff': ('strongsubj', 'negative'),
#  'chagrin': ('strongsubj', 'negative'),
#  'challenge': ('weaksubj', 'negative'),
#  'challenging': ('weaksubj', 'negative'),
#  'champion': ('weaksubj', 'positive'),
#  'champ': ('weaksubj', 'positive'),
#  'chant': ('weaksubj', 'neutral'),
#  'chaos': ('strongsubj', 'negative'),
#  'chaotic': ('strongsubj', 'negative'),
#  'charisma': ('strongsubj', 'negative'),
#  'charismatic': ('strongsubj', 'positive'),
#  'charitable': ('weaksubj', 'positive'),
#  'charity': ('weaksubj', 'positive'),
#  'charm': ('strongsubj', 'positive'),
#  'charming': ('strongsubj', 'positive'),
#  'charmingly': ('strongsubj', 'positive'),
#  'chaste': ('strongsubj', 'positive'),
#  'chasten': ('strongsubj', 'negative'),
#  'chastise': ('strongsubj', 'negative'),
#  'chastisement': ('strongsubj', 'negative'),
#  'chatter': ('strongsubj', 'negative'),
#  'chatterbox': ('strongsubj', 'negative'),
#  'cheapen': ('strongsubj', 'negative'),
#  'cheap': ('strongsubj', 'negative'),
#  'cheat': ('strongsubj', 'negative'),
#  'cheater': ('strongsubj', 'negative'),
#  'cheer': ('strongsubj', 'positive'),
#  'cheery': ('strongsubj', 'positive'),
#  'cheerful': ('strongsubj', 'positive'),
#  'cheerless': ('strongsubj', 'negative'),
#  'cherish': ('strongsubj', 'positive'),
#  'cherished': ('strongsubj', 'positive'),
#  'cherub': ('strongsubj', 'positive'),
#  'chic': ('strongsubj', 'positive'),
#  'chide': ('strongsubj', 'negative'),
#  'childish': ('strongsubj', 'negative'),
#  'chill': ('weaksubj', 'negative'),
#  'chilly': ('weaksubj', 'negative'),
#  'chit': ('strongsubj', 'negative'),
#  'chivalry': ('strongsubj', 'positive'),
#  'chivalrous': ('strongsubj', 'positive'),
#  'choppy': ('weaksubj', 'negative'),
#  'choke': ('weaksubj', 'negative'),
#  'chore': ('weaksubj', 'negative'),
#  'chronic': ('weaksubj', 'negative'),
#  'chum': ('weaksubj', 'positive'),
#  'civility': ('strongsubj', 'positive'),
#  'civilization': ('weaksubj', 'positive'),
#  'civilize': ('weaksubj', 'positive'),
#  'civil': ('weaksubj', 'positive'),
#  'claim': ('weaksubj', 'neutral'),
#  'clamor': ('weaksubj', 'negative'),
#  'clamorous': ('weaksubj', 'negative'),
#  'clandestine': ('weaksubj', 'neutral'),
#  'clarity': ('weaksubj', 'positive'),
#  'clash': ('weaksubj', 'negative'),
#  'classic': ('weaksubj', 'positive'),
#  'clean': ('weaksubj', 'positive'),
#  'cleanliness': ('weaksubj', 'positive'),
#  'cleanse': ('weaksubj', 'positive'),
#  'clear': ('weaksubj', 'positive'),
#  'clear-cut': ('strongsubj', 'positive'),
#  'clearer': ('strongsubj', 'positive'),
#  'clearly': ('strongsubj', 'positive'),
#  'clever': ('strongsubj', 'positive'),
#  'cliche': ('strongsubj', 'negative'),
#  'cliched': ('strongsubj', 'negative'),
#  'clique': ('weaksubj', 'negative'),
#  'clog': ('weaksubj', 'negative'),
#  'close': ('weaksubj', 'negative'),
#  'closeness': ('strongsubj', 'positive'),
#  'cloud': ('strongsubj', 'negative'),
#  'clout': ('strongsubj', 'positive'),
#  'clumsy': ('strongsubj', 'negative'),
#  'co-operation': ('weaksubj', 'positive'),
#  'coarse': ('weaksubj', 'negative'),
#  'coax': ('strongsubj', 'positive'),
#  'cocky': ('strongsubj', 'negative'),
#  'coddle': ('weaksubj', 'positive'),
#  'coerce': ('strongsubj', 'negative'),
#  'coercion': ('strongsubj', 'negative'),
#  'coercive': ('strongsubj', 'negative'),
#  'cogent': ('strongsubj', 'positive'),
#  'cohesive': ('weaksubj', 'positive'),
#  'cogitate': ('strongsubj', 'neutral'),
#  'cognizance': ('weaksubj', 'neutral'),
#  'cognizant': ('strongsubj', 'neutral'),
#  'cohere': ('weaksubj', 'positive'),
#  'coherence': ('strongsubj', 'positive'),
#  'coherent': ('weaksubj', 'positive'),
#  'cohesion': ('weaksubj', 'positive'),
#  'cold': ('weaksubj', 'negative'),
#  'coldly': ('strongsubj', 'negative'),
#  'collapse': ('weaksubj', 'negative'),
#  'collide': ('weaksubj', 'negative'),
#  'collude': ('strongsubj', 'negative'),
#  'collusion': ('strongsubj', 'negative'),
#  'colorful': ('weaksubj', 'positive'),
#  'colossal': ('weaksubj', 'positive'),
#  'combative': ('weaksubj', 'negative'),
#  'comeback': ('weaksubj', 'positive'),
#  'comedy': ('weaksubj', 'negative'),
#  'comely': ('strongsubj', 'positive'),
#  'comfort': ('weaksubj', 'positive'),
#  'comfortable': ('weaksubj', 'positive'),
#  'comfortably': ('weaksubj', 'positive'),
#  'comforting': ('strongsubj', 'positive'),
#  'comical': ('weaksubj', 'negative'),
#  'commend': ('strongsubj', 'positive'),
#  'commendable': ('strongsubj', 'positive'),
#  'commendably': ('strongsubj', 'positive'),
#  'commensurate': ('weaksubj', 'positive'),
#  'commonsense': ('weaksubj', 'positive'),
#  'commonsensible': ('weaksubj', 'positive'),
#  'commonsensibly': ('weaksubj', 'positive'),
#  ...}

# %%
with open('data/subjectivity_dictionary.json', 'w') as file:
    json.dump(subjectivity_lexicon, file)

# %%
for a in df.iloc[11075].adjectives:
    try:
        print(a, subjectivity_lexicon[a])
    except:
        pass
# Out:
# successful ('weaksubj', 'positive')
# notable ('strongsubj', 'positive')
# close ('weaksubj', 'negative')
# famous ('weaksubj', 'positive')
# active ('weaksubj', 'positive')
# spiritual ('strongsubj', 'positive')
# spiritual ('strongsubj', 'positive')
# intimate ('strongsubj', 'neutral')
# civil ('weaksubj', 'positive')
# devoted ('strongsubj', 'positive')
# holy ('weaksubj', 'positive')

# %%
df.iloc[11075]
# Out:
# id                                                     Q6697285
# name                                               Lucille Kahn
# wiki-title                                         Lucille Kahn
# gender                                             ['Q6581072']
# occupation                               ['Q33999', 'Q2259451']
# overview      Lucille Kahn (1902–1995) was a successful Broa...
# adjectives    [successful, notable, human, close, early, fam...
# Name: 11075, dtype: object
